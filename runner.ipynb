# %%
# %pip install -r requirements.txt
# !python data_pipeline.py
# !python generate_visuals.py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# 2026-07-12 16:19:33,250 - INFO - Starting campaign data merge...
# 2026-07-12 16:19:33,403 - INFO - Existing file 'D:\OneDrive - Cloud Wellness Pvt Ltd\Wallpapers\Hemal sureja\COLLEGE_NOTES (SEM-1,2,3) BDA\final year project Data (kitoko)\kitoko project files\Kitoko_Campaign_Data.xlsx' will be overwritten.
# 2026-07-12 16:19:33,726 - INFO - Successfully merged 104 files and saved to 'D:\OneDrive - Cloud Wellness Pvt Ltd\Wallpapers\Hemal sureja\COLLEGE_NOTES (SEM-1,2,3) BDA\final year project Data (kitoko)\kitoko project files\Kitoko_Campaign_Data.xlsx'!
# 2026-07-12 16:19:33,726 - INFO - Starting RFM calculation...
# 2026-07-12 16:19:35,316 - INFO - Successfully loaded Order Details.
# 2026-07-12 16:19:35,341 - INFO - RFM DataFrame created. Sample:
#            asin  Recency  Frequency  ...  M_Score RFM_Score        Segment
# 6    B0CZ97WPWL        0       2027  ...        5       555  Top Performer
# ...
